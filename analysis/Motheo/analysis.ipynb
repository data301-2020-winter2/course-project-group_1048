# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./../../data/raw/listings.csv")

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20201210194755   2020-12-11
# 1  5858  https://www.airbnb.com/rooms/5858  20201210194755   2020-12-11
# 2  7918  https://www.airbnb.com/rooms/7918  20201210194755   2020-12-11
# 3  8142  https://www.airbnb.com/rooms/8142  20201210194755   2020-12-11
# 4  8339  https://www.airbnb.com/rooms/8339  20201210194755   2020-12-10
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          description  \
# 0  Cleaning Protocol: Our cleaners follow the Air...
# 1  <b>The space</b><br />We live in a large Victo...
# ...

# %%
import seaborn as sns

# %%
project_fuctions = df[['name', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']]
project_fuctions.dropna()
# Out:
#                                                    name  \
# 0                 Bright, Modern Garden Unit - 1BR/1BTH
# 1                                    Creative Sanctuary
# 2            A Friendly Room - UCSF/USF - San Francisco
# 3     Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                       Historic Alamo Square Victorian
# ...                                                 ...
# 6958     The Oasis: Mid Century Noe VIEW Indoor-Outdoor
# 6961     Designer Apartment in the heart of North Beach
# 7029     Ocean beach,  Private Studio &  Garage Parking
# 7031  Peaceful Private Room C, 3 Min Walk To Ocean B...
# 7044          Entire Modern Apartment In SF City Center
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  1
# 2                                  8
# 3                                  8
# 4                                  2
# ...                              ...
# ...

# %%
sns.pairplot(df[['calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']])

# %%
###I wanted to see the distribution of different types of accommodation offered by each host.

# %%
sns.displot(data=project_fuctions, x="calculated_host_listings_count", y="reviews_per_month")

# %%
###i wanted to find out if there is a relation between the total count of types of accommodation offered by each host and the reviews per month. I would like to narrow down to finding the relation between airbnbs that offer at most 5 accomodations and the review per month

# %%
small_airbnb = project_fuctions[project_fuctions['calculated_host_listings_count'] < 6]
sns.countplot(data = small_airbnb, y = 'reviews_per_month')
# Out:
# <AxesSubplot:xlabel='count', ylabel='reviews_per_month'>
